# %%
import pandas as pd
import seaborn as sns
import os
import os.path as osp
import matplotlib.pyplot as plt
import collections

# %%
path = "summarized_results_main.csv"
df = pd.read_csv(path)
dst = 'figures'
model='resnet34'
drop_names = ['ERK', "SNIP", 'iterSNIP', 'Rand', 'SynFlow', 'SynFlow_no_Skip']

# %%
subdf = df.loc[df.model_type == model]

# %%
df2 = pd.read_csv('summarized_results.csv')

# %%
df2.loc[df2.prune_type == 'GraSP', 'prune_type'] = "GraSP_no_Skip"

# %%
df2.loc[df2.prune_type == 'SynFlow', 'prune_type'] = "SynFlow_no_Skip"

# %%
subdf = pd.concat([subdf, df2], ignore_index=True)

# %%
subdf = subdf.reindex()

# %%
subdf
# Out:
#    model_type       prune_type  global_density  sparsity_mean  sparsity_std  \
# 0    resnet34              ERK            0.01       0.061731      0.167480
# 1    resnet34            GraSP            0.01       0.083990      0.106943
# 2    resnet34             Rand            0.01       0.009950      0.000428
# 3    resnet34             SNIP            0.01       0.103926      0.169674
# 4    resnet34          SynFlow            0.01       0.083138      0.128337
# 5    resnet34         iterSNIP            0.01       0.116637      0.182442
# 6    resnet34              ERK            0.40       0.731112      0.296462
# 7    resnet34            GraSP            0.40       0.427355      0.159256
# 8    resnet34             Rand            0.40       0.399382      0.002421
# 9    resnet34             SNIP            0.40       0.795088      0.309623
# 10   resnet34          SynFlow            0.40       0.773753      0.295106
# 11   resnet34         iterSNIP            0.40       0.795063      0.309851
# 12   resnet34              ERK            0.05       0.190113      0.248978
# 13   resnet34            GraSP            0.05       0.193145      0.147441
# 14   resnet34             Rand            0.05       0.050036      0.000847
# 15   resnet34             SNIP            0.05       0.247941      0.241859
# 16   resnet34          SynFlow            0.05       0.253634      0.280530
# 17   resnet34         iterSNIP            0.05       0.260580      0.249467
# 18   resnet34              ERK            0.20       0.510978      0.348131
# 19   resnet34            GraSP            0.20       0.400224      0.156820
# 20   resnet34             Rand            0.20       0.199691      0.001945
# 21   resnet34             SNIP            0.20       0.535024      0.291139
# 22   resnet34          SynFlow            0.20       0.522342      0.321775
# 23   resnet34         iterSNIP            0.20       0.539833      0.293099
# 24   resnet34              ERK            0.10       0.311166      0.295365
# 25   resnet34            GraSP            0.10       0.275947      0.153654
# 26   resnet34             Rand            0.10       0.099950      0.000923
# 27   resnet34             SNIP            0.10       0.363203      0.272279
# 28   resnet34          SynFlow            0.10       0.367037      0.319680
# 29   resnet34         iterSNIP            0.10       0.375028      0.278695
# 30   resnet34    GraSP_no_Skip            0.01       0.069056      0.086781
# 31   resnet34  SynFlow_no_Skip            0.01       0.076418      0.126548
# 32   resnet34    GraSP_no_Skip            0.40       0.426336      0.166803
# 33   resnet34  SynFlow_no_Skip            0.40       0.772352      0.306036
# 34   resnet34    GraSP_no_Skip            0.05       0.165526      0.126810
# 35   resnet34  SynFlow_no_Skip            0.05       0.245319      0.276526
# 36   resnet34    GraSP_no_Skip            0.20       0.395807      0.161867
# 37   resnet34  SynFlow_no_Skip            0.20       0.529957      0.327377
# 38   resnet34    GraSP_no_Skip            0.10       0.252806      0.141118
# 39   resnet34  SynFlow_no_Skip            0.10       0.369230      0.321129
#
#     sparsity_count    sm_mean     sm_std  sm_count    rm_mean  ...  \
# 0              1.0  -0.158907   3.029241  0.936937   0.339646  ...
# 1              1.0  -0.936949   2.019945  0.891892  -2.243287  ...
# 2              1.0  -1.170956   0.292588  0.162162  -0.543807  ...
# 3              1.0  -2.452659   3.369833  0.891892  -4.449799  ...
# 4              1.0   2.188948   1.222183  0.918919   2.608199  ...
# 5              1.0  -1.294367   4.436272  0.747748  -1.696863  ...
# 6              1.0  19.128025  14.119635  1.000000  24.095799  ...
# 7              1.0   4.842181   2.686583  1.000000   8.145587  ...
# 8              1.0   3.557404   1.498026  1.000000   7.634712  ...
# 9              1.0   7.841149  17.080893  1.000000  11.936591  ...
# 10             1.0  24.871208   4.736382  1.000000  29.337737  ...
# 11             1.0   8.652994  16.043530  1.000000  12.841214  ...
# 12             1.0   0.675318   4.915724  1.000000   2.430714  ...
# 13             1.0  -2.263916   5.777717  1.000000  -2.429755  ...
# 14             1.0  -1.126658   0.659457  0.972973  -0.018770  ...
# 15             1.0  -6.127014   8.723792  1.000000  -7.394503  ...
# 16             1.0   4.294023   2.966455  1.000000   5.297247  ...
# 17             1.0  -4.966274   9.223415  0.936937  -4.933433  ...
# 18             1.0   8.424008  11.375032  1.000000  12.113513  ...
# 19             1.0   2.638573   4.984047  1.000000   5.470112  ...
# 20             1.0  -0.221653   0.753418  0.972973   2.549542  ...
# 21             1.0  -7.459386  20.416026  1.000000  -5.883206  ...
# 22             1.0  11.654822   5.437630  1.000000  14.172929  ...
# 23             1.0  -6.374556  20.168241  1.000000  -4.397417  ...
# 24             1.0   2.614149   7.329067  1.000000   5.182006  ...
# 25             1.0  -2.515447   7.882992  1.000000  -1.409638  ...
# 26             1.0  -1.088949   0.789938  0.972973   0.740116  ...
# 27             1.0  -7.232341  13.766121  1.000000  -7.501074  ...
# 28             1.0   6.788345   4.134946  1.000000   8.194275  ...
# 29             1.0  -5.170222  13.973377  1.000000  -4.665609  ...
# 30             1.0  -2.095269   2.075875  0.980392  -3.338469  ...
# 31             1.0   2.429157   1.020240  1.000000   2.870744  ...
# 32             1.0   4.647791   5.157925  1.000000   8.249768  ...
# 33             1.0  26.284689   3.703635  1.000000  31.138902  ...
# 34             1.0  -5.499526   7.508141  1.000000  -5.225253  ...
# 35             1.0   4.447401   2.694533  1.000000   5.535916  ...
# 36             1.0   1.599279  10.083480  1.000000   4.754617  ...
# 37             1.0  12.274161   4.811983  1.000000  14.992078  ...
# 38             1.0  -4.241362  10.448422  1.000000  -2.695317  ...
# 39             1.0   6.816192   3.940120  1.000000   8.399775  ...
#
#     rm_norm_mean  rm_norm_std  rm_norm_count  sm_norm_mean  sm_norm_std  \
# 0      -0.038573     0.192309       0.936937     -0.082251     0.205818
# 1      -0.279543     0.326956       0.891892     -0.088174     0.182458
# 2      -0.065324     0.010150       0.162162     -0.148596     0.030829
# 3      -0.496166     0.365391       0.891892     -0.194590     0.232067
# 4       0.174117     0.111858       0.918919      0.165493     0.089133
# 5      -0.122335     0.280333       0.747748     -0.060419     0.287400
# 6       0.643194     0.377924       1.000000      0.591302     0.433648
# 7       0.260937     0.079632       1.000000      0.176901     0.092762
# 8       0.230557     0.006645       1.000000      0.124257     0.059049
# 9       0.353244     0.442006       1.000000      0.299073     0.468981
# 10      0.704078     0.141347       1.000000      0.673399     0.155732
# 11      0.375161     0.421529       1.000000      0.319430     0.452040
# 12      0.122846     0.236976       1.000000      0.016586     0.273833
# 13     -0.144798     0.358202       1.000000     -0.105158     0.286147
# 14     -0.012024     0.032495       0.972973     -0.098878     0.045203
# 15     -0.418020     0.534697       1.000000     -0.272083     0.414582
# 16      0.227880     0.180686       1.000000      0.207525     0.152129
# 17     -0.226007     0.495516       0.936937     -0.203389     0.441170
# 18      0.407220     0.371913       1.000000      0.322574     0.425789
# 19      0.201505     0.142266       1.000000      0.120286     0.163471
# 20      0.106989     0.006497       0.972973     -0.002750     0.045150
# 21     -0.103716     0.603145       1.000000     -0.135519     0.601090
# 22      0.433549     0.224709       1.000000      0.398653     0.222062
# 23     -0.053910     0.581536       1.000000     -0.101169     0.593572
# 24      0.223379     0.295681       1.000000      0.117387     0.338686
# 25     -0.025505     0.310876       1.000000     -0.068030     0.304384
# 26      0.041132     0.012301       0.972973     -0.065036     0.045668
# 27     -0.290981     0.589999       1.000000     -0.234500     0.507774
# 28      0.300287     0.213318       1.000000      0.278622     0.190312
# 29     -0.146545     0.536297       1.000000     -0.142610     0.506652
# 30     -0.447556     0.385337       0.980392     -0.217529     0.215407
# 31      0.193148     0.095443       1.000000      0.173698     0.072985
# 32      0.260968     0.115841       1.000000      0.167345     0.150465
# 33      0.723783     0.135612       1.000000      0.690876     0.155136
# 34     -0.286013     0.454475       1.000000     -0.287434     0.404400
# 35      0.244440     0.169266       1.000000      0.216870     0.150813
# 36      0.182434     0.249130       1.000000      0.086062     0.295699
# 37      0.450135     0.218340       1.000000      0.411757     0.218548
# 38     -0.074860     0.395023       1.000000     -0.147427     0.414630
# 39      0.307609     0.211577       1.000000      0.278556     0.196342
#
#     sm_norm_count  perc_ram_by_rm_mean  perc_ram_by_irm_mean       acc  \
# 0        0.936937             0.126126              0.045045  0.811567
# 1        0.891892             0.198198              0.495495  0.861567
# 2        0.162162             0.000000              0.000000  0.674233
# 3        0.891892             0.081081              0.378378  0.860233
# 4        0.918919             0.891892              0.819820  0.862633
# 5        0.747748             0.171171              0.684685  0.865167
# 6        1.000000             1.000000              1.000000  0.887200
# 7        1.000000             0.972973              1.000000  0.876167
# 8        1.000000             1.000000              0.990991  0.873833
# 9        1.000000             0.711712              1.000000  0.888633
# 10       1.000000             1.000000              1.000000  0.887933
# 11       1.000000             0.711712              1.000000  0.887733
# 12       1.000000             0.873874              0.801802  0.870033
# 13       1.000000             0.495495              0.801802  0.871500
# 14       0.972973             0.486486              0.180180  0.815600
# 15       1.000000             0.207207              0.801802  0.877300
# 16       1.000000             0.936937              0.900901  0.881333
# 17       0.936937             0.342342              0.918919  0.881667
# 18       1.000000             1.000000              1.000000  0.887433
# 19       1.000000             0.837838              1.000000  0.875367
# 20       0.972973             0.972973              0.945946  0.864533
# 21       1.000000             0.504505              0.981982  0.884233
# 22       1.000000             1.000000              0.972973  0.885367
# 23       1.000000             0.522523              0.990991  0.885400
# 24       1.000000             1.000000              1.000000  0.876767
# 25       1.000000             0.558559              0.900901  0.872567
# 26       0.972973             0.954955              0.891892  0.842433
# 27       1.000000             0.387387              0.891892  0.880767
# 28       1.000000             1.000000              0.927928  0.884167
# 29       1.000000             0.414414              0.945946  0.885467
# 30       0.980392             0.196078              0.392157  0.800167
# 31       1.000000             0.970588              0.931373  0.834767
# 32       1.000000             0.941176              1.000000  0.568367
# 33       1.000000             1.000000              1.000000  0.766900
# 34       1.000000             0.411765              0.745098  0.715533
# 35       1.000000             0.970588              0.990196  0.855467
# 36       1.000000             0.843137              1.000000  0.535767
# 37       1.000000             1.000000              1.000000  0.761333
# 38       1.000000             0.509804              0.950980  0.525800
# 39       1.000000             1.000000              1.000000  0.860667
#
#      acc_std
# 0   0.004834
# 1   0.001701
# 2   0.010281
# 3   0.002902
# 4   0.001450
# 5   0.003301
# 6   0.003105
# 7   0.000416
# 8   0.000924
# 9   0.002316
# 10  0.002409
# 11  0.001258
# 12  0.002196
# 13  0.001015
# 14  0.001082
# 15  0.003064
# 16  0.001762
# 17  0.002581
# 18  0.001601
# 19  0.001234
# 20  0.005623
# 21  0.002635
# 22  0.003485
# 23  0.002883
# 24  0.005701
# 25  0.003444
# 26  0.002495
# 27  0.001193
# 28  0.001301
# 29  0.002715
# 30  0.033714
# 31  0.014953
# 32  0.073011
# 33  0.130870
# 34  0.135885
# 35  0.001850
# 36  0.149186
# 37  0.098181
# 38  0.127487
# 39  0.012444
#
# [40 rows x 61 columns]

# %%
import numpy as np
import math
sns.set(font_scale=1.5)
def double_axis_plot(data, x, y1, y2,  hue_type, drop=None, x_name=None, y1_name = None, y2_name = None, title=None, save=False, ylim=None, xlim=None, y1_std=None, y2_std=None):
    data = data.copy()
    plt.figure(figsize=(12, 8))
    if drop:
        for d in drop:
            data = data.loc[data.prune_type != d]    
   
    data = data.sort_values(by=[x])
    ax = sns.lineplot(data=data, x=x, y=y1, hue=hue_type, marker='o', linewidth=2.5, markersize=9)

    ax.grid()
    ax.set_ylabel(y1_name)
    ax.set_xlabel(x_name)
    ax.set_title(title)
    if y2 is not None:
        ax2 = ax.twinx()
        sns.lineplot(data=data, x=x, y=y2, hue=hue_type, ax=ax2, linestyle="dashed", marker='P', linewidth=2.5, markersize=12)

        ax.get_legend().remove()
        ax2.grid()
        ax2.set_ylabel(y2_name)
    ax.grid()
    ax2.grid()
    
    def std(name):
        if 'mean' in name:
            std = name.replace('mean', 'std')
        else:
            std = name + "_std"
        return std
    for x_i in data[hue_type].unique().tolist():
        subdata = data.loc[data[hue_type] == x_i]
        if y1_std:
            print(x_i)
            ax.fill_between(subdata[x], y1=subdata[y1] - subdata[y1_std], y2=subdata[y1] +  subdata[y1_std], alpha=.5)
        if y2_std:
            ax2.fill_between(subdata[x], y1=subdata[y2] - subdata[y2_std], y2=subdata[y2] + subdata[y2_std], alpha=.5)

    if ylim is not None:
        ax.set_ylim(ylim)
    if xlim is not None:
        ax.set_xlim(xlim)
    if save:
        plt.tight_layout()
        plt.savefig(osp.join(dst, title+".svg"))

# %%
double_axis_plot(subdf, x='global_density', y1='acc', y2="irm_norm_mean", y1_std='acc_std', hue_type='prune_type', x_name="Network Density", y1_name='performance', y2_name="IMDB",
                drop=drop_names, title=f"Perf V. Density V. IMDB of {model}", save=True)

# %%
double_axis_plot(subdf, x='global_density', y1='acc', y2="rm_norm_mean", hue_type='prune_type', x_name="Network Density", y1_name='performance', y2_name="\u0394 r",
                drop=drop_names, title=f"Perf V. Density V. \u0394 r of {model}", save=True, y1_std="acc_std")

# %%
double_axis_plot(subdf, x='global_density', y1='rm_norm_mean', y2="random_factor_mean", hue_type='prune_type', x_name="global density", y1_name='IMDB', y2_name="NaRC",
                drop=drop_names, title=f"IMDB V. Performance V. RandomCoef of {model}", save=True)

# %%
double_axis_plot(subdf, x='global_density', y1='rm_norm_mean', y2="random_factor_mean", hue_type='prune_type', x_name="global density", y1_name='IMDB', y2_name="NaRC",
                drop=drop_names, title=f"IMDB V. Performance V. RandomCoef of {model}", save=False)

# %%
double_axis_plot(subdf, x='global_density', y1='acc', y2="random_factor_mean", hue_type='prune_type', x_name="Network density", y1_name='Performance', y2_name="NaRC",
                drop=drop_names, title=f"Performance V. Density V. RandomCoef of {model}", save=True, y1_std='acc_std')
# Out:
# GraSP
# GraSP_no_Skip
